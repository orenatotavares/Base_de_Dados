# %% [markdown]
# # Importando as Bibliotecas e o DataFrame

# %%
#importando bibliotecas
import pandas as pd
import numpy as np
from google.colab import data_table
data_table.enable_dataframe_formatter()
import warnings
warnings.filterwarnings('ignore')

# Importando a Classe Cores
class bcolors:
    OKGREEN = '\033[92m' #GREEN
    OkBLUE = '\033[94m' #BLUE
    WARNING = '\033[93m' #YELLOW
    FAIL = '\033[91m' #RED
    RESET = '\033[0m' #RESET COLOR

# %%
# England Premier League
df_ENG1 = pd.read_excel('https://github.com/futpythontrader/YouTube/blob/main/England%20Premier%20League_20212022.xlsx?raw=true')
# England Championship
df_ENG2 = pd.read_excel('https://github.com/futpythontrader/YouTube/blob/main/England%20Championship_20212022.xlsx?raw=true')

# France Ligue 1
df_FRA1 = pd.read_excel('https://github.com/futpythontrader/YouTube/blob/main/France%20Ligue%201_20212022.xlsx?raw=true')
# France Ligue 2
df_FRA2 = pd.read_excel('https://github.com/futpythontrader/YouTube/blob/main/France%20Ligue%202_20212022.xlsx?raw=true')

# Germany Bundesliga
df_GER1 = pd.read_excel('https://github.com/futpythontrader/YouTube/blob/main/Germany%20Bundesliga_20212022.xlsx?raw=true')
# Germany 2. Bundesliga
df_GER2 = pd.read_excel('https://github.com/futpythontrader/YouTube/blob/main/Germany%202.%20Bundesliga_20212022.xlsx?raw=true')

# Italy Serie A
df_ITA1 = pd.read_excel('https://github.com/futpythontrader/YouTube/blob/main/Italy%20Serie%20A_20212022.xlsx?raw=true')
# Italy Serie B
df_ITA2 = pd.read_excel('https://github.com/futpythontrader/YouTube/blob/main/Italy%20Serie%20B_20212022.xlsx?raw=true')

# Spain La Liga
df_SPA1 = pd.read_excel('https://github.com/futpythontrader/YouTube/blob/main/Spain%20La%20Liga_20212022.xlsx?raw=true')
# Spain Segunda División
df_SPA2 = pd.read_excel('https://github.com/futpythontrader/YouTube/blob/main/Spain%20Segunda%20Divisi%C3%B3n_20212022.xlsx?raw=true')

# %% [markdown]
# # Fazendo os Filtros de Rodadas

# %%
df = df_SPA2
df = df[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Goals_H','FT_Goals_A','FT_TotalGoals','FT_Odds_BTTS_Yes']]

# %%
df1 = df.groupby(['Rodada']).get_group(1)
df2 = df.groupby(['Rodada']).get_group(2)
df3 = df.groupby(['Rodada']).get_group(3)
df4 = df.groupby(['Rodada']).get_group(4)
df5 = df.groupby(['Rodada']).get_group(5)
df6 = df.groupby(['Rodada']).get_group(6)
df7 = df.groupby(['Rodada']).get_group(7)
df8 = df.groupby(['Rodada']).get_group(8)
df9 = df.groupby(['Rodada']).get_group(9)
df10 = df.groupby(['Rodada']).get_group(10)
df11 = df.groupby(['Rodada']).get_group(11)
df12 = df.groupby(['Rodada']).get_group(12)
df13 = df.groupby(['Rodada']).get_group(13)
df14 = df.groupby(['Rodada']).get_group(14)
df15 = df.groupby(['Rodada']).get_group(15)
df16 = df.groupby(['Rodada']).get_group(16)
df17 = df.groupby(['Rodada']).get_group(17)
df18 = df.groupby(['Rodada']).get_group(18)
df19 = df.groupby(['Rodada']).get_group(19)
df20 = df.groupby(['Rodada']).get_group(20)
df21 = df.groupby(['Rodada']).get_group(21)
df22 = df.groupby(['Rodada']).get_group(22)
df23 = df.groupby(['Rodada']).get_group(23)
df24 = df.groupby(['Rodada']).get_group(24)
df25 = df.groupby(['Rodada']).get_group(25)
df26 = df.groupby(['Rodada']).get_group(26)
df27 = df.groupby(['Rodada']).get_group(27)
df28 = df.groupby(['Rodada']).get_group(28)
df29 = df.groupby(['Rodada']).get_group(29)
df30 = df.groupby(['Rodada']).get_group(30)
df31 = df.groupby(['Rodada']).get_group(31)
df32 = df.groupby(['Rodada']).get_group(32)
df33 = df.groupby(['Rodada']).get_group(33)
df34 = df.groupby(['Rodada']).get_group(34)
df35 = df.groupby(['Rodada']).get_group(35)
df36 = df.groupby(['Rodada']).get_group(36)
df37 = df.groupby(['Rodada']).get_group(37)
df38 = df.groupby(['Rodada']).get_group(38)

# %% [markdown]
# # Filtros

# %%
# Filtros de Odds
Odd_Min_Back_Fav = 1.50
Odd_Max_Back_Fav = 2.20
Odd_Min_Over25 = 1.50
Odd_Max_Over25 = 2.20
Odd_Min_BTTS = 1.50
Odd_Max_BTTS = 2.20

# %%
def lay_goleada_punter():

    count = 0
    for i,j in zip(df_LGP.Home, df_LGP.Away):
            
            mandante = i
            visitante = j
            Gols_Marcados_Home = df_liga[['Home','FT_Goals_H']].groupby('Home').sum()
            Gols_Marcados_Away = df_liga[['Away','FT_Goals_A']].groupby('Away').sum()
            Gols_Marcados = pd.concat([Gols_Marcados_Home, Gols_Marcados_Away],axis=1)
            Gols_Marcados['Gols_Marcados'] = Gols_Marcados.FT_Goals_H + Gols_Marcados.FT_Goals_A
            Gols_Marcados = Gols_Marcados[['Gols_Marcados']]
            Gols_Marcados.index = Gols_Marcados.index.set_names(['Time'])
            Gols_Marcados = Gols_Marcados.sort_values(['Gols_Marcados'], ascending=False)
            Gols_Marcados = Gols_Marcados.rename_axis('index').reset_index()
            Gols_Marcados.reset_index(inplace=True, drop=True)
            Gols_Marcados.index = Gols_Marcados.index.set_names(['Nº'])
            Gols_Marcados = Gols_Marcados.rename(index=lambda x: x + 1)
            Gols_Marcados.columns = ['Time','Gols Marcados']
            # display(Gols_Marcados)

            Gols_Sofridos_Home = df_liga[['Home','FT_Goals_A']].groupby('Home').sum()
            Gols_Sofridos_Away = df_liga[['Away','FT_Goals_H']].groupby('Away').sum()
            Gols_Sofridos = pd.concat([Gols_Sofridos_Home, Gols_Sofridos_Away],axis=1)
            Gols_Sofridos['Gols_Sofridos'] = Gols_Sofridos.FT_Goals_H + Gols_Sofridos.FT_Goals_A
            Gols_Sofridos = Gols_Sofridos[['Gols_Sofridos']]
            Gols_Sofridos.index = Gols_Sofridos.index.set_names(['Time'])
            Gols_Sofridos = Gols_Sofridos.sort_values(['Gols_Sofridos'], ascending=True)
            Gols_Sofridos = Gols_Sofridos.rename_axis('index').reset_index()
            Gols_Sofridos.reset_index(inplace=True, drop=True)
            Gols_Sofridos.index = Gols_Sofridos.index.set_names(['Nº'])
            Gols_Sofridos = Gols_Sofridos.rename(index=lambda x: x + 1)
            Gols_Sofridos.columns = ['Time','Gols Sofridos']
            # display(Gols_Sofridos)

            print(""); print( mandante + " x " + visitante)
            flt_goleada1 = (Gols_Marcados.index > 5) & (Gols_Marcados.index <=15);
            df_gol1 = Gols_Marcados[flt_goleada1]
            lista1 = (sorted(df_gol1['Time'].unique()));
            flt_goleada2 = (Gols_Sofridos.index <=15);
            df_gol2 = Gols_Sofridos[flt_goleada2]
            lista2 = (sorted(df_gol2['Time'].unique()));
            if mandante in lista1 and mandante in lista2 and visitante in lista1 and visitante in lista2:
                # print(""); print( mandante + " x " + visitante)
                print(bcolors.OKGREEN + "Fazer a Entrada no Lay Goleada Punter" + bcolors.RESET)
                
            else:
                print(bcolors.FAIL + "Não Trabalhar Lay Goleada Punter" + bcolors.RESET)

# %% [markdown]
# # Análise do Lay Goleada (Rodada por Rodada)

# %%
df_liga = [df1,df2,df3,df4]
df_liga = pd.concat(df_liga)
df_jogos = df5

# %%
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]

# %%
lay_goleada_punter()

# %%
df_LGP

# %%
df_liga = [df1,df2,df3,df4,df5]
df_liga = pd.concat(df_liga)
df_jogos = df6
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
df_LGP
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6]
df_liga = pd.concat(df_liga)
df_jogos = df7
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
df_LGP
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7]
df_liga = pd.concat(df_liga)
df_jogos = df8
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8]
df_liga = pd.concat(df_liga)
df_jogos = df9
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9]
df_liga = pd.concat(df_liga)
df_jogos = df10
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]
df_liga = pd.concat(df_liga)
df_jogos = df11
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11]
df_liga = pd.concat(df_liga)
df_jogos = df12
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12]
df_liga = pd.concat(df_liga)
df_jogos = df13
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13]
df_liga = pd.concat(df_liga)
df_jogos = df14
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14]
df_liga = pd.concat(df_liga)
df_jogos = df15
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15]
df_liga = pd.concat(df_liga)
df_jogos = df16
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16]
df_liga = pd.concat(df_liga)
df_jogos = df17
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17]
df_liga = pd.concat(df_liga)
df_jogos = df18
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18]
df_liga = pd.concat(df_liga)
df_jogos = df19
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19]
df_liga = pd.concat(df_liga)
df_jogos = df20
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20]
df_liga = pd.concat(df_liga)
df_jogos = df21
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21]
df_liga = pd.concat(df_liga)
df_jogos = df22
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22]
df_liga = pd.concat(df_liga)
df_jogos = df23
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23]
df_liga = pd.concat(df_liga)
df_jogos = df24
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24]
df_liga = pd.concat(df_liga)
df_jogos = df25
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25]
df_liga = pd.concat(df_liga)
df_jogos = df26
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26]
df_liga = pd.concat(df_liga)
df_jogos = df27
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27]
df_liga = pd.concat(df_liga)
df_jogos = df28
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28]
df_liga = pd.concat(df_liga)
df_jogos = df29
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29]
df_liga = pd.concat(df_liga)
df_jogos = df30
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30]
df_liga = pd.concat(df_liga)
df_jogos = df31
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31]
df_liga = pd.concat(df_liga)
df_jogos = df32
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32]
df_liga = pd.concat(df_liga)
df_jogos = df33
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33]
df_liga = pd.concat(df_liga)
df_jogos = df34
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34]
df_liga = pd.concat(df_liga)
df_jogos = df35
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35]
df_liga = pd.concat(df_liga)
df_jogos = df36
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36]
df_liga = pd.concat(df_liga)
df_jogos = df37
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %%
df_liga = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37]
df_liga = pd.concat(df_liga)
df_jogos = df38
flt = (df_jogos.FT_Odds_H >= Odd_Min_Back_Fav) & (df_jogos.FT_Odds_H <= Odd_Max_Back_Fav) & (df_jogos.FT_Odds_Over25 >= Odd_Min_Over25) & (df_jogos.FT_Odds_Over25 <= Odd_Max_Over25) & (df_jogos.FT_Odds_BTTS_Yes >= Odd_Min_BTTS) & (df_jogos.FT_Odds_BTTS_Yes <= Odd_Max_BTTS)
df_LGP = df_jogos[flt]
df_LGP = df_LGP[['Rodada','Home','Away','FT_Odds_H','FT_Odds_D','FT_Odds_A','FT_Odds_Over25','FT_Odds_BTTS_Yes','FT_Goals_H','FT_Goals_A']]
display(df_LGP, lay_goleada_punter())

# %% [markdown]
# # Greens x Reds

# %%
# ING 1 - 14 GREENS E 1 RED
# ING 2 - 8 GREENS E 1 RED
# FRA 1 - 20 GREENS E 1 RED
# FRA 2 - 9 GREENS
# GER 1 - 27 GREENS E 1 RED
# GER 2 - 23 GREENS
# ITA 1 - 15 GREENS E 1 RED
# ITA 2 - 17 GREENS E 6 REDS
# SPA 1 - 17 GREENS E 1 RED
# SPA 2 - 3 GREENS

greens = 153
reds = 12

# %%
responsabilidade = 100
odd_media = 13.4
stake = responsabilidade / (odd_media - 1)
print("Você lucrou R$", stake*greens - reds*responsabilidade)

# %%
greens = 136
reds = 6
