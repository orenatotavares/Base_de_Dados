# %%
# Importando as Bibliotecas Básicas
import pandas as pd
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
# spi_matches.csv contains match-by-match SPI ratings and forecasts back to 2016.
df1 = pd.read_csv("https://projects.fivethirtyeight.com/soccer-api/club/spi_matches.csv")

# spi_matches_latest.csv contains match-by-match SPI ratings and forecasts for each league's latest season.
df2 = pd.read_csv("https://projects.fivethirtyeight.com/soccer-api/club/spi_matches_latest.csv")

# spi_global_rankings.csv contains current SPI ratings and rankings for men's club teams.
df3 = pd.read_csv("https://projects.fivethirtyeight.com/soccer-api/club/spi_global_rankings.csv")

# spi_global_rankings_intl.csv contains current SPI ratings and rankings for men's international teams.
df4 = pd.read_csv("https://projects.fivethirtyeight.com/soccer-api/international/spi_global_rankings_intl.csv")

# %%
df1.info()

# %%
df1 = df1[['season','date','league','team1','team2','spi1','spi2','prob1','probtie','prob2','proj_score1','proj_score2','score1','score2','xg1','xg2']]
df0 = df1[df1.league == "Spanish Primera Division"]

# %%
df0

# %%
df2

# %%
df3

# %%
df4
