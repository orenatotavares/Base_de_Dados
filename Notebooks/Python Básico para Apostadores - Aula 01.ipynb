# %% [markdown]
# # Utilizando o Python como uma Calculadora

# %%
2 + 2
# Out:
# 4

# %%
2 * 7
# Out:
# 14

# %% [markdown]
# # Criar Variáveis

# %%
nome = "FutPythonTrader"

# %%
nome
# Out:
# 'FutPythonTrader'

# %%
Time = "Palmeiras"

# %%
Odd = 1.80

# %%
Estádio = "Arena Palmeiras"
Cidade = "São Paulo"
País = "Brasil"
Rodada = 16

# %% [markdown]
# # Utilizando o Comando Print

# %%
print(Time)
# Out:
# São Paulo

# %%
print(Time, Estádio, Cidade, País)
# Out:
# São Paulo Morumbi São Paulo Brasil

# %%
print("Quando é o jogo do São Paulo?")
# Out:
# Quando é o jogo do São Paulo?

# %%
print("O " + Time + " vai jogar amanhã no estádio do " + Estádio + " na cidade de " + Cidade + " pela Liga do " + País)
# Out:
# O Palmeiras vai jogar amanhã no estádio do Arena Palmeiras na cidade de São Paulo pela Liga do Brasil

# %% [markdown]
# # Tipos Primitivos

# %% [markdown]
# Inteiros - int

# %%
num_1 = 5
num_2 = 2

# %%
soma = num_1 + num_2

# %%
print(soma)
# Out:
# 7

# %%
type(soma)
# Out:
# int

# %% [markdown]
# Pontos Flutuantes - float

# %%
num_3 = 0.4
num_4 = 0.5

# %%
soma2 = num_3 + num_4

# %%
print(soma2)
# Out:
# 0.9

# %%
type(soma2)
# Out:
# float

# %% [markdown]
# Função de Arredondamento - round

# %%
prob = 72
odd = round(100 / prob, 2)

# %%
print(odd)
# Out:
# 1.39

# %% [markdown]
# String - str

# %%
Palpite = "Fortaleza vai sair da Zona de Rebaixamento"

# %%
print(Palpite)
# Out:
# Fortaleza vai sair da Zona de Rebaixamento

# %%
type(Palpite)
# Out:
# str

# %% [markdown]
# Booleano - bool

# %%
Var1 = True
Var2 = False

# %%
type(Var2)
# Out:
# bool

# %% [markdown]
# # Print Novamente

# %%
print(str(num_1), "titulos tem o", Time)
# Out:
# 5 titulos tem o Palmeiras

# %%
num_1 = str(num_1)

# %%
type(num_1)
# Out:
# str
