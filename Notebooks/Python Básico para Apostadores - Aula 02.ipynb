# %% [markdown]
# # Lista - list

# %%
lista = ['Cuiabá', 4, 'Atlético Mineiro', 2, 'Over 1.5', 'Odd', 1.70]

# %%
type(lista)
# Out:
# list

# %% [markdown]
# # Tupla - tuple

# %%
tupla = ('Cuiabá', 4, 'Atlético Mineiro', 2, 'Over 1.5', 'Odd', 1.70)

# %%
type(tupla)
# Out:
# tuple

# %% [markdown]
# # Conjunto - set

# %%
conjunto = {'Cuiabá', 4, 'Atlético Mineiro', 2, 'Over 1.5', 'Odd', 1.70, True, False}

# %%
type(conjunto)
# Out:
# set

# %% [markdown]
# # Dicionários - dict

# %%
dicionario = {'Mandante': 'Cuiabá',
              'Visitante': 'Atlético Mineiro',
              'Gols_Home': 0,
              'Gols_Away': 0,
              'Odds_Home': 4,
              'Odds_Away': 2,
              'BTTS': False}

# %%
type(dicionario)
# Out:
# dict

# %% [markdown]
# # Entrada de Dados - input()

# %%
odd = float(input('Digite a Odd do Lay Goleada: '))
# Out:
# Digite a Odd do Lay Goleada: 15.5

# %%
type(odd)
# Out:
# float

# %% [markdown]
# # Operações Matemáticas

# %% [markdown]
# ADIÇÃO (+)

# %%
Odd_H = float(input('Digite a Odd do Time Mandante: '))
Odd_A = float(input('Digite a Odd do Time Visitante: '))
Odd_D = float(input('Digite a Odd do Empate: '))
Gol_H = int(input('Digite Quantos Gols o Mandante Marcou: '))
Gol_A = int(input('Digite Quantos Gols o Visitante Marcou: '))
# Out:
# Digite a Odd do Time Mandante: 1.8
# Digite a Odd do Time Visitante: 3.2
# Digite a Odd do Empate: 3
# Digite Quantos Gols o Mandante Marcou: 2
# Digite Quantos Gols o Visitante Marcou: 1

# %%
Gols_Total = Gol_H + Gol_A

# %%
print(Gols_Total)
# Out:
# 3

# %% [markdown]
# SUBTRAÇÃO (-)

# %%
Saldo_Gols_H = Gol_H - Gol_A

# %%
print(Saldo_Gols_H)
# Out:
# 1

# %% [markdown]
# MULTIPLICAÇÃO (*)

# %%
Variavel = Odd_H * Gol_H

# %%
print(Variavel)
# Out:
# 3.6

# %% [markdown]
# DIVISÃO (/)

# %%
prob = 100/Odd_H

# %%
print(prob)
# Out:
# 55.55555555555556

# %% [markdown]
# EXPONENCIAÇÃO (**)

# %%
VAR = Odd_H**2

# %%
print(VAR)
# Out:
# 3.24

# %% [markdown]
# ORDEM DE AVALIAÇÃO DOS OPERADORES

# %%
# Exponenciação
# Multiplicação, Divisão
# Adição, Subtração

# %%
formula = (Odd_H+Odd_A)*Gol_H**2-Gol_A/Odd_H

# %%
print(formula)
# Out:
# 19.444444444444443

# %% [markdown]
# # Operações Relacionais

# %%
# Igual (==)
# Diferente (!=)
# Maior Que (>)
# Menor Que (<)
# Maior ou Igual (>=)
# Menor ou Igual (<=)

# %%
Odd_H < Odd_A
# Out:
# True

# %%
2 == '2'
# Out:
# False
